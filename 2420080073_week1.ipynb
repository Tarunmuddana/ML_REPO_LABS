# %%
print ("HELLO WORLD")
# Out:
# HELLO WORLD

# %%
string = "hi"
number = 1
fl     = 1.2
print(type(string))
print(type(number))
print(type(fl))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
CamleCasing = "cammel"
normal ="normal"
noraml123= "WE"
normal_13="wewe"

# %%
a = 10
b = a
c = a

# %%
list = []
for i in range(4):
    list.append(input())
print(list)
# Out:
#  hi
#  ji
#  jiji
#  iojioj
# ['hi', 'ji', 'jiji', 'iojioj']

# %%
dict = {"car1":1985,"car2":1922}
print(dict)
# Out:
# {'car1': 1985, 'car2': 1922}
